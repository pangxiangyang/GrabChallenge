# %%
# Break dataset into multiple dataset per unique geohash
def splitDataset(data):
  dict_of_df = {}
  alluniqueGeohash = data.geohash6.unique()
  geospecificdata = pd.DataFrame();
  for geohash in alluniqueGeohash[:100]:
    keyName = geohash;
    dict_of_df[keyName] = data.loc[data['geohash6'] == keyName]
    print( keyName + " dataset created")
  return dict_of_df, alluniqueGeohash;

# %%
# Convert day & timestamp into date
def parseToDateTime( geospecificdata):

  currentDate = date.today()
  maxDay = max(geospecificdata['day']) + 1;

  for index,row in geospecificdata.iterrows():    
      historyStart = currentDate - timedelta(days= maxDay -row['day'])  
      dateTime = datetime.datetime.strptime( str( historyStart) + row['timestamp'], "%Y-%m-%d%H:%M")
      geospecificdata.at[index,'Datetime'] = dateTime;

  newdf = geospecificdata.sort_values(by=[('Datetime' )], inplace = False ).copy()
  return newdf

# %%
# Split into train and test sets
def splitTrainTest( data ):
    
  train_size = int(len(data) * trainRatio)
  test_size = len(data) - train_size
  trainData, testData = data[:train_size], data.tail(test_size)
  
  # Get the subset of the data for training
  training_set = trainData.iloc[:, 3].values

  # Create input for training
  import numpy as np
  X_train = []
  y_train =[]
  for i in range(nrofinputs, len(training_set)):
      X_train.append(training_set[i-nrofinputs:i]);
      y_train.append(training_set[i])

  X_train, y_train = np.array(X_train), np.array(y_train)
  if(len(X_train) > 0 ):
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
  return X_train,y_train,trainData,testData

# %%
# Plot demand vs DateTime
def plotData( geospecificdata):

  plt.figure(figsize=(20,10))
  plt.plot(geospecificdata['Datetime'], geospecificdata['demand'], linestyle = 'solid', marker = 'None')
  plt.title( geospecificdata.iloc[0,0])

# %%
def validate( regressor, trainData, testData, isLSTM ):
    training_set = trainData.iloc[:, 3].values
    # Create test data for prediction
    test_set = training_set[-nrofinputs:]
    #test_set = np.concatenate(( test_set ,(testData.iloc[:, 3].values)) )

    predictedValues = [];
    results = [];
    X_test = np.array(test_set[0:nrofinputs]  );
    X_test = X_test.reshape(-1,nrofinputs)
    predictedValues = regressor.predict(X_test)
    results.append( predictedValues[0])
    X_test = np.append( np.delete(X_test, 0 ), predictedValues[0] );

    # Make prediction
    for i in range(nrofinputs + 1, len(testData) + nrofinputs ):
        if( isLSTM):
            X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
        X_test = X_test.reshape(-1,nrofinputs)
        predictedValues = regressor.predict(X_test);
        results.append( predictedValues[0])
        X_test = np.append( np.delete(X_test, 0 ), predictedValues[0] );
    return results;

# %%
def compileAndVisualizeResult( data, predictedValues, isVisualize, name ):
  
  # Get actualValues
  train_size = int(len(data) * trainRatio )
  test_size = len(data) - train_size
  actualValues = data['demand'].tail(test_size).values
  # Calculate RMSE
  rmse = sqrt(mean_squared_error(actualValues, predictedValues ))
  print('Test RMSE: %.3f' % rmse)
  
  # Store result in dictionary
  result = pd.DataFrame();
  result["ActualValues"] = actualValues;
  result["PredictedValues"] = predictedValues;
  result['RMSE'] = rmse;
  dict_of_results[name] = result;
 
  # Visualising the results
  if( isVisualize):
      plt.plot(data['Datetime'].tail(test_size), actualValues, color = 'red', label = 'Actual demand')
      plt.plot(data['Datetime'].tail(test_size), predictedValues, color = 'blue', label = 'Predicted demand')
      plt.title('Actual vs predicted')
      plt.xlabel('Datetime')
      plt.ylabel('Demand')
      plt.legend()
      plt.show()

# %%
def buildGradientBoostingRegressor( X_train, y_train ):
    clf = GradientBoostingRegressor(n_estimators=200, max_depth=3, random_state=23)
    lr_train = X_train.reshape(-1,nrofinputs)
    clf.fit(lr_train, y_train)
    return clf;

# %%
def buildRandomForestRegressor( X_train, y_train ):
    # Initialize the famous Random Forest Regressor from scikit-learn
    clf = RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=23)
    lr_train = X_train.reshape(-1,nrofinputs)
    clf.fit(lr_train, y_train)
    return clf;

# %%
def buildLinearRegressor( X_train, y_train):
    #implement linear regression
    from sklearn.linear_model import LinearRegression
    model = LinearRegression()
    lr_train = X_train.reshape(-1,nrofinputs)
    model.fit(lr_train,y_train)
    return model;

# %%
def exportModel( model,name, isKeras, isLR, isGBR ):
  if( isKeras):
    name = "gdrive/My Drive/Machine Learning Playground/Models/" + name + ".h5"
    model.save( name )
  else:
    #name = "C:/Users/PXY/Desktop/Models/" + name + ".sav"
    if(isLR):
      name = "C:/Users/PXY/Desktop/Models_LR/" + name + ".sav";
      #name = "gdrive/My Drive/Machine Learning Playground/Models_LR/" + name + ".sav"
    elif( isGBR ):
      name = "gdrive/My Drive/Machine Learning Playground/Models_GBR/" + name + ".sav"
    else:
      name = "gdrive/My Drive/Machine Learning Playground/Models_RFR/" + name + ".sav"
    joblib.dump( model, name );

# %%
# Get data for testing
def processTestData( data, nrofinputs ):
  # Get the subset of the data for testing
  testing_set = data.iloc[:, 3].values
  # Create input for testing
  X_test = []
  X_test.append(testing_set[len(testing_set)-nrofinputs:len(testing_set)]);

  X_test = np.array(X_test)
  if(len(X_test) > 0 ):
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
  return X_test

# %%
def getNrofInputs(data):
    nrofdata = len(data);
    nrofdays = len(data.day.unique() )
    averagedataperday = int( nrofdata / nrofdays );
    nrOfInput = averagedataperday * 7;
    return nrOfInput

# %%
def predict( testFilepath, modelFolderpath ):
    
    dict_of_test_results = {};
    # Test filepath
    data = pd.read_csv( testFilepath );
    
    # Split test file into multiple dataset
    dict_of_test_df, alluniqueTestGeohash = splitDataset(data);
    count = 1;
    
    # Define number of predictions, default will be 5
    nroftimesteppredicted = 5;
    
    with open('nrofinputs.pkl', 'rb') as f:
        dict_of_nr_inputs = pickle.load(f)
    
    # Loop thorough all GeoHash
    for geoHash in alluniqueTestGeohash:
        print("Testing-----------------------------", count, geoHash)
        df = parseToDateTime( dict_of_test_df[geoHash] );
        
        nrofinputs = dict_of_nr_inputs[geoHash];
        
        # Get the number of inputs from history
        X_test = processTestData( df, nrofinputs );
        X_test_array = np.array(X_test).reshape(1,X_test.shape[1] )
    
        # Get the pre-trained model based on geohash code
        filename = modelFolderpath + geoHash + ".sav"
        model = joblib.load(filename)
        results = [];
        
        # Perform recurvie multi-step forecast
        # 1st predicted value will be used as input to predict next value
        for i in range( 0, nroftimesteppredicted ):
            inputRow = np.array( X_test_array[0] )
            inputRow = inputRow.reshape(1,inputRow.shape[0])
            predictedValues = model.predict(inputRow )
            results.append(predictedValues[0])
            X_test_array = np.append( np.delete(X_test_array, 0 ), predictedValues[0] );
            X_test_array = X_test_array.reshape(1,X_test.shape[1] )
        
        count = count + 1;
        dict_of_test_results[geoHash] = results;
        # Plot the results
        #plt.figure(figsize=(20,10))
        #plt.plot(df.iloc[len(df) - len(results):len(df)]['Datetime'], results, linestyle = 'solid', marker = 'None')
        #plt.title( geoHash)
    return dict_of_test_results;

# %%
# Import data
import numpy as np
import pandas as pd
import datetime 
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf
import pickle
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.externals import joblib
from math import sqrt
from datetime import date, timedelta

pd.options.mode.chained_assignment = None

#Mount google drive
#from google.colab import drive 
#drive.mount('/content/gdrive', force_remount=True)

#Read the file from google drive

#Read the file from google drive
data = pd.read_csv( 'C:/Users/PXY/Desktop/training.csv' )
#data = pd.read_csv( 'gdrive/My Drive/Machine Learning Playground/training.csv' )

# Split into multiple datasets based on Hash
dict_of_model = {};
dict_of_df, alluniqueGeohash = splitDataset(data);
# Out:
# qp03wc dataset created
# qp03pn dataset created
# qp09sw dataset created
# qp0991 dataset created
# qp090q dataset created
# qp03tu dataset created
# qp096d dataset created
# qp03nr dataset created
# qp093r dataset created
# qp03r2 dataset created
# qp09kb dataset created
# qp03rp dataset created
# qp03w9 dataset created
# qp096m dataset created
# qp091u dataset created
# qp03md dataset created
# qp099z dataset created
# qp0990 dataset created
# qp03mf dataset created
# qp09fu dataset created
# qp091w dataset created
# qp0dhw dataset created
# qp09fh dataset created
# qp0961 dataset created
# qp03zr dataset created
# qp09de dataset created
# qp09g8 dataset created
# qp0d0k dataset created
# qp09m0 dataset created
# qp03yx dataset created
# qp09u8 dataset created
# qp09df dataset created
# qp0djh dataset created
# qp03rs dataset created
# qp03q7 dataset created
# qp03wp dataset created
# qp09u3 dataset created
# qp094k dataset created
# qp09bd dataset created
# qp03wm dataset created
# qp0d0j dataset created
# qp093d dataset created
# qp09kz dataset created
# qp06nc dataset created
# qp06pk dataset created
# qp03yv dataset created
# qp09bq dataset created
# qp09k0 dataset created
# qp06pe dataset created
# qp03w7 dataset created
# qp098e dataset created
# qp03q6 dataset created
# qp06n8 dataset created
# qp0925 dataset created
# qp09b2 dataset created
# qp096t dataset created
# qp09gh dataset created
# qp03y1 dataset created
# qp0djw dataset created
# qp09t8 dataset created
# qp094j dataset created
# qp09k3 dataset created
# qp09ss dataset created
# qp09hm dataset created
# qp03wt dataset created
# qp092d dataset created
# qp03rh dataset created
# qp03w0 dataset created
# qp03y9 dataset created
# qp09ge dataset created
# qp03ye dataset created
# qp096w dataset created
# qp03x3 dataset created
# qp03xu dataset created
# qp03mz dataset created
# qp093x dataset created
# qp09dk dataset created
# qp09hy dataset created
# qp0d19 dataset created
# qp09dm dataset created
# qp09sz dataset created
# qp06pw dataset created
# qp09gw dataset created
# qp02zz dataset created
# qp0dj0 dataset created
# qp03yk dataset created
# qp09g1 dataset created
# qp099b dataset created
# qp08fx dataset created
# qp09e5 dataset created
# qp09fd dataset created
# qp09tp dataset created
# qp09hj dataset created
# qp0900 dataset created
# qp0d5g dataset created
# qp09gy dataset created
# qp08gy dataset created
# qp09jq dataset created
# qp03yd dataset created
# qp094q dataset created
# qp08bq dataset created
# qp02ze dataset created
# qp0901 dataset created
# qp03wz dataset created
# qp03p3 dataset created
# qp09cm dataset created
# qp09tn dataset created
# qp03zd dataset created
# qp03z4 dataset created
# qp03ym dataset created
# qp09g3 dataset created
# qp09d3 dataset created
# qp03td dataset created
# qp091y dataset created
# qp09t9 dataset created
# qp097f dataset created
# qp09fz dataset created
# qp09ht dataset created
# qp03jz dataset created
# qp09dg dataset created
# qp03wn dataset created
# qp03tg dataset created
# qp093u dataset created
# qp098j dataset created
# qp03x6 dataset created
# qp09bn dataset created
# qp09uj dataset created
# qp09tr dataset created
# qp0981 dataset created
# qp03mw dataset created
# qp08cn dataset created
# qp09kv dataset created
# qp09cc dataset created
# qp03mu dataset created
# qp09fm dataset created
# qp03y6 dataset created
# qp03yg dataset created
# qp09sn dataset created
# qp03r7 dataset created
# qp03rg dataset created
# qp098k dataset created
# qp0d1f dataset created
# qp03q2 dataset created
# qp09bt dataset created
# qp03r6 dataset created
# qp09eb dataset created
# qp03qc dataset created
# qp03xh dataset created
# qp03me dataset created
# qp0993 dataset created
# qp0dhu dataset created
# qp0dh9 dataset created
# qp09ev dataset created
# qp03nx dataset created
# qp08gn dataset created
# qp03x4 dataset created
# qp03w8 dataset created
# qp09b4 dataset created
# qp094r dataset created
# qp0979 dataset created
# qp03m3 dataset created
# qp03zu dataset created
# qp090s dataset created
# qp08bh dataset created
# qp03zg dataset created
# qp03zn dataset created
# qp03m6 dataset created
# qp0d59 dataset created
# qp093p dataset created
# qp09f9 dataset created
# qp03wx dataset created
# qp09bh dataset created
# qp03x0 dataset created
# qp09db dataset created
# qp03zp dataset created
# qp0d56 dataset created
# qp092k dataset created
# qp08un dataset created
# qp099t dataset created
# qp09u9 dataset created
# qp03zk dataset created
# qp0dhc dataset created
# qp03qv dataset created
# qp0d53 dataset created
# qp03mv dataset created
# qp03r9 dataset created
# qp02yc dataset created
# qp097k dataset created
# qp03x9 dataset created
# qp0985 dataset created
# qp09gx dataset created
# qp097v dataset created
# qp03we dataset created
# qp0d0h dataset created
# qp0984 dataset created
# qp0d4w dataset created
# qp096v dataset created
# qp09e3 dataset created
# qp09ud dataset created
# qp09s6 dataset created
# qp08gt dataset created
# qp0djv dataset created
# qp03p1 dataset created
# qp03rz dataset created
# qp095b dataset created
# qp06pn dataset created
# qp0d12 dataset created
# qp03zm dataset created
# qp09v1 dataset created
# qp09dt dataset created
# qp0d58 dataset created
# qp095r dataset created
# qp09cd dataset created
# qp09b5 dataset created
# qp099r dataset created
# qp03w4 dataset created
# qp03t6 dataset created
# qp03x7 dataset created
# qp09b1 dataset created
# qp09kx dataset created
# qp0d4c dataset created
# qp096j dataset created
# qp09um dataset created
# qp09f1 dataset created
# qp09e9 dataset created
# qp0d54 dataset created
# qp09cp dataset created
# qp0951 dataset created
# qp090r dataset created
# qp02zj dataset created
# qp097x dataset created
# qp0980 dataset created
# qp09uz dataset created
# qp0dj6 dataset created
# qp0dhg dataset created
# qp092s dataset created
# qp03zj dataset created
# qp0d5f dataset created
# qp094t dataset created
# qp0d1h dataset created
# qp098n dataset created
# qp03xd dataset created
# qp03z0 dataset created
# qp096g dataset created
# qp096u dataset created
# qp03px dataset created
# qp09gg dataset created
# qp09dd dataset created
# qp0dj1 dataset created
# qp0djs dataset created
# qp094m dataset created
# qp06pc dataset created
# qp094w dataset created
# qp09hr dataset created
# qp03pd dataset created
# qp08cm dataset created
# qp0d4q dataset created
# qp03qu dataset created
# qp09u1 dataset created
# qp097u dataset created
# qp03nq dataset created
# qp093y dataset created
# qp09s9 dataset created
# qp03rk dataset created
# qp09em dataset created
# qp094z dataset created
# qp0929 dataset created
# qp03pe dataset created
# qp099y dataset created
# qp09u0 dataset created
# qp09hn dataset created
# qp03r5 dataset created
# qp095c dataset created
# qp03z8 dataset created
# qp03yc dataset created
# qp09vw dataset created
# qp03ze dataset created
# qp06pm dataset created
# qp0987 dataset created
# qp0d4n dataset created
# qp06ph dataset created
# qp09fj dataset created
# qp092p dataset created
# qp09gu dataset created
# qp0dh0 dataset created
# qp096x dataset created
# qp09uv dataset created
# qp03jx dataset created
# qp09tx dataset created
# qp09f7 dataset created
# qp092e dataset created
# qp09cu dataset created
# qp09ew dataset created
# qp0959 dataset created
# qp0d4y dataset created
# qp08bk dataset created
# qp03xy dataset created
# qp096p dataset created
# qp03z3 dataset created
# qp09hs dataset created
# qp03qm dataset created
# qp099s dataset created
# qp03ty dataset created
# qp03jy dataset created
# qp03xx dataset created
# qp09t5 dataset created
# qp096z dataset created
# qp098q dataset created
# qp03z5 dataset created
# qp03yf dataset created
# qp09gf dataset created
# qp03qy dataset created
# qp0d4e dataset created
# qp0970 dataset created
# qp03nz dataset created
# qp093z dataset created
# qp09vv dataset created
# qp0d0c dataset created
# qp0d01 dataset created
# qp06n9 dataset created
# qp09w5 dataset created
# qp03zw dataset created
# qp0941 dataset created
# qp09b0 dataset created
# qp0dj4 dataset created
# qp099g dataset created
# qp092h dataset created
# qp0djj dataset created
# qp03x8 dataset created
# qp09fx dataset created
# qp06p7 dataset created
# qp092x dataset created
# qp03qd dataset created
# qp03pr dataset created
# qp02zh dataset created
# qp03t7 dataset created
# qp03xn dataset created
# qp03ny dataset created
# qp09s8 dataset created
# qp09be dataset created
# qp09dj dataset created
# qp02zc dataset created
# qp09sf dataset created
# qp0949 dataset created
# qp03wb dataset created
# qp03p2 dataset created
# qp09fv dataset created
# qp0dh4 dataset created
# qp09ef dataset created
# qp03p4 dataset created
# qp09vq dataset created
# qp09cx dataset created
# qp09kc dataset created
# qp09sj dataset created
# qp02zk dataset created
# qp09vz dataset created
# qp03zf dataset created
# qp03w1 dataset created
# qp099m dataset created
# qp03x5 dataset created
# qp03q3 dataset created
# qp09en dataset created
# qp0953 dataset created
# qp099v dataset created
# qp08cy dataset created
# qp0d4f dataset created
# qp099h dataset created
# qp09gs dataset created
# qp03rd dataset created
# qp03qs dataset created
# qp0997 dataset created
# qp03zz dataset created
# qp0948 dataset created
# qp09cj dataset created
# qp03tf dataset created
# qp06nf dataset created
# qp09jv dataset created
# qp09md dataset created
# qp0909 dataset created
# qp09er dataset created
# qp03ws dataset created
# qp09dn dataset created
# qp09vy dataset created
# qp09b3 dataset created
# qp097h dataset created
# qp093g dataset created
# qp0958 dataset created
# qp0dh8 dataset created
# qp03xz dataset created
# qp0djm dataset created
# qp094h dataset created
# qp092w dataset created
# qp03re dataset created
# qp06pu dataset created
# qp09ft dataset created
# qp0d0g dataset created
# qp095k dataset created
# qp0946 dataset created
# qp03mq dataset created
# qp03zs dataset created
# qp09k2 dataset created
# qp09ed dataset created
# qp09kf dataset created
# qp03jq dataset created
# qp09vk dataset created
# qp03rc dataset created
# qp094y dataset created
# qp08gx dataset created
# qp03yb dataset created
# qp03rn dataset created
# qp09mp dataset created
# qp03ru dataset created
# qp09mx dataset created
# qp0989 dataset created
# qp09vt dataset created
# qp090x dataset created
# qp09ez dataset created
# qp0d51 dataset created
# qp09ep dataset created
# qp03r3 dataset created
# qp09sd dataset created
# qp0d4u dataset created
# qp090c dataset created
# qp0dj7 dataset created
# qp0d05 dataset created
# qp03my dataset created
# qp0974 dataset created
# qp090k dataset created
# qp0d5b dataset created
# qp095j dataset created
# qp09sh dataset created
# qp099e dataset created
# qp0978 dataset created
# qp03w2 dataset created
# qp03ww dataset created
# qp094b dataset created
# qp098r dataset created
# qp090p dataset created
# qp09f0 dataset created
# qp09e4 dataset created
# qp03xm dataset created
# qp09d7 dataset created
# qp09g2 dataset created
# qp03p9 dataset created
# qp02zr dataset created
# qp03z7 dataset created
# qp08by dataset created
# qp09mu dataset created
# qp02zm dataset created
# qp0dht dataset created
# qp08b4 dataset created
# qp092t dataset created
# qp095v dataset created
# qp09yh dataset created
# qp095m dataset created
# qp03mr dataset created
# qp097y dataset created
# qp0d0v dataset created
# qp09gv dataset created
# qp0dhs dataset created
# qp097t dataset created
# qp09d6 dataset created
# qp03wd dataset created
# qp08gq dataset created
# qp0d4b dataset created
# qp093w dataset created
# qp092m dataset created
# qp0982 dataset created
# qp09bm dataset created
# qp093c dataset created
# qp0d00 dataset created
# qp03r8 dataset created
# qp0927 dataset created
# qp09dc dataset created
# qp06py dataset created
# qp03m7 dataset created
# qp096e dataset created
# qp03qj dataset created
# qp03pp dataset created
# qp09sk dataset created
# qp02zy dataset created
# qp09cw dataset created
# qp09f5 dataset created
# qp09g9 dataset created
# qp09f6 dataset created
# qp0923 dataset created
# qp02zt dataset created
# qp09ky dataset created
# qp08gr dataset created
# qp09uu dataset created
# qp092r dataset created
# qp02z1 dataset created
# qp06p6 dataset created
# qp090e dataset created
# qp0960 dataset created
# qp03qx dataset created
# qp03wg dataset created
# qp03py dataset created
# qp097b dataset created
# qp03pf dataset created
# qp09bk dataset created
# qp0963 dataset created
# qp06p9 dataset created
# qp09sr dataset created
# qp03pb dataset created
# qp096h dataset created
# qp095n dataset created
# qp097e dataset created
# qp08gz dataset created
# qp03m8 dataset created
# qp06pg dataset created
# qp09fk dataset created
# qp09eu dataset created
# qp09hk dataset created
# qp03qw dataset created
# qp09gp dataset created
# qp092n dataset created
# qp094u dataset created
# qp03tv dataset created
# qp0d0f dataset created
# qp03r4 dataset created
# qp09d8 dataset created
# qp0d0w dataset created
# qp03y0 dataset created
# qp03t8 dataset created
# qp03mk dataset created
# qp03r0 dataset created
# qp09d5 dataset created
# qp03nd dataset created
# qp097c dataset created
# qp0d52 dataset created
# qp02zp dataset created
# qp09fq dataset created
# qp03qb dataset created
# qp03rm dataset created
# qp09dh dataset created
# qp096y dataset created
# qp03qk dataset created
# qp06pt dataset created
# qp09hw dataset created
# qp03wj dataset created
# qp03rb dataset created
# qp0971 dataset created
# qp097d dataset created
# qp096s dataset created
# qp09b6 dataset created
# qp09e7 dataset created
# qp03tx dataset created
# qp09ek dataset created
# qp09f2 dataset created
# qp093v dataset created
# qp09mq dataset created
# qp09dw dataset created
# qp092q dataset created
# qp03tz dataset created
# qp0d1w dataset created
# qp03pk dataset created
# qp09d4 dataset created
# qp03q4 dataset created
# qp03xr dataset created
# qp03tb dataset created
# qp096k dataset created
# qp03wv dataset created
# qp09vp dataset created
# qp03tc dataset created
# qp03zt dataset created
# qp03xb dataset created
# qp03p8 dataset created
# qp098g dataset created
# qp09e6 dataset created
# qp09uw dataset created
# qp03qh dataset created
# qp09fg dataset created
# qp03xp dataset created
# qp0992 dataset created
# qp06pv dataset created
# qp03qg dataset created
# qp03q5 dataset created
# qp03q8 dataset created
# qp03mb dataset created
# qp03mg dataset created
# qp09e1 dataset created
# qp03x1 dataset created
# qp09fr dataset created
# qp09ue dataset created
# qp03nw dataset created
# qp097z dataset created
# qp0945 dataset created
# qp09cy dataset created
# qp03yy dataset created
# qp09sp dataset created
# qp092j dataset created
# qp09dp dataset created
# qp09yn dataset created
# qp09ug dataset created
# qp03m9 dataset created
# qp09k4 dataset created
# qp03w5 dataset created
# qp0d4g dataset created
# qp09ut dataset created
# qp03xf dataset created
# qp03x2 dataset created
# qp09et dataset created
# qp09s7 dataset created
# qp03zc dataset created
# qp03rf dataset created
# qp03rt dataset created
# qp0djy dataset created
# qp0922 dataset created
# qp09dv dataset created
# qp0d48 dataset created
# qp0d4t dataset created
# qp03pv dataset created
# qp096f dataset created
# qp02z9 dataset created
# qp03ms dataset created
# qp0d0m dataset created
# qp0dhb dataset created
# qp09mn dataset created
# qp03yw dataset created
# qp03qf dataset created
# qp09u5 dataset created
# qp0djk dataset created
# qp09ds dataset created
# qp09g6 dataset created
# qp09gj dataset created
# qp02zx dataset created
# qp0921 dataset created
# qp0d15 dataset created
# qp06ns dataset created
# qp0944 dataset created
# qp03xk dataset created
# qp09t1 dataset created
# qp0950 dataset created
# qp09h5 dataset created
# qp090w dataset created
# qp09cg dataset created
# qp090j dataset created
# qp09h0 dataset created
# qp09wp dataset created
# qp0d0n dataset created
# qp09jn dataset created
# qp0d07 dataset created
# qp03q9 dataset created
# qp0934 dataset created
# qp03jw dataset created
# qp02zd dataset created
# qp0d1k dataset created
# qp06pj dataset created
# qp0d1g dataset created
# qp09kt dataset created
# qp091z dataset created
# qp0924 dataset created
# qp098p dataset created
# qp09uc dataset created
# qp09vn dataset created
# qp094p dataset created
# qp03pu dataset created
# qp06ne dataset created
# qp09t0 dataset created
# qp09tw dataset created
# qp0d16 dataset created
# qp093q dataset created
# qp095u dataset created
# qp03rx dataset created
# qp0986 dataset created
# qp0dh6 dataset created
# qp03ts dataset created
# qp09v0 dataset created
# qp03wy dataset created
# qp0djt dataset created
# qp091n dataset created
# qp09mw dataset created
# qp09t2 dataset created
# qp0920 dataset created
# qp09un dataset created
# qp0d0b dataset created
# qp03z6 dataset created
# qp03pw dataset created
# qp09uy dataset created
# qp09q5 dataset created
# qp093s dataset created
# qp09fs dataset created
# qp02zs dataset created
# qp09m1 dataset created
# qp03xc dataset created
# qp095q dataset created
# qp09vj dataset created
# qp0903 dataset created
# qp03mc dataset created
# qp09us dataset created
# qp0dhe dataset created
# qp099j dataset created
# qp09ex dataset created
# qp09u4 dataset created
# qp096b dataset created
# qp03z1 dataset created
# qp03ys dataset created
# qp03rj dataset created
# qp06nd dataset created
# qp09sc dataset created
# qp03yq dataset created
# qp08br dataset created
# qp09c9 dataset created
# qp098u dataset created
# qp03ps dataset created
# qp096c dataset created
# qp09ux dataset created
# qp09bz dataset created
# qp03t9 dataset created
# qp03xt dataset created
# qp09d2 dataset created
# qp09vx dataset created
# qp03m2 dataset created
# qp09g0 dataset created
# qp03zv dataset created
# qp095y dataset created
# qp0dhh dataset created
# qp03tt dataset created
# qp094g dataset created
# qp06p0 dataset created
# qp098m dataset created
# qp097s dataset created
# qp0d5e dataset created
# qp099w dataset created
# qp0d4s dataset created
# qp09es dataset created
# qp03xj dataset created
# qp09t4 dataset created
# qp09v2 dataset created
# qp09uf dataset created
# qp03qn dataset created
# qp03yu dataset created
# qp09ku dataset created
# qp09hh dataset created
# qp0d4d dataset created
# qp09gr dataset created
# qp0d06 dataset created
# qp08gp dataset created
# qp095e dataset created
# qp03wk dataset created
# qp09th dataset created
# qp03z2 dataset created
# qp0dj8 dataset created
# qp03wf dataset created
# qp099d dataset created
# qp0947 dataset created
# qp0d1c dataset created
# qp0983 dataset created
# qp09gt dataset created
# qp09k9 dataset created
# qp0968 dataset created
# qp0d1m dataset created
# qp095t dataset created
# qp09eq dataset created
# qp06nu dataset created
# qp09fw dataset created
# qp08cp dataset created
# qp09e8 dataset created
# qp06p4 dataset created
# qp06p1 dataset created
# qp09g5 dataset created
# qp090t dataset created
# qp09s2 dataset created
# qp09b7 dataset created
# qp0d02 dataset created
# qp09vr dataset created
# qp06ps dataset created
# qp06pb dataset created
# qp03r1 dataset created
# qp09fb dataset created
# qp09u6 dataset created
# qp09fy dataset created
# qp0954 dataset created
# qp03wr dataset created
# qp06p5 dataset created
# qp03rq dataset created
# qp0996 dataset created
# qp0933 dataset created
# qp08bm dataset created
# qp02zw dataset created
# qp09sm dataset created
# qp0dj9 dataset created
# qp09bj dataset created
# qp09bw dataset created
# qp0d49 dataset created
# qp03qq dataset created
# qp0962 dataset created
# qp0dh2 dataset created
# qp090b dataset created
# qp03y7 dataset created
# qp09bp dataset created
# qp03q1 dataset created
# qp09vu dataset created
# qp08bj dataset created
# qp0969 dataset created
# qp0976 dataset created
# qp09gk dataset created
# qp03xw dataset created
# qp098c dataset created
# qp0dhy dataset created
# qp09cv dataset created
# qp0dnj dataset created
# qp0djn dataset created
# qp06nb dataset created
# qp03xs dataset created
# qp094x dataset created
# qp095w dataset created
# qp03v9 dataset created
# qp09k1 dataset created
# qp0d42 dataset created
# qp03xq dataset created
# qp03wh dataset created
# qp09d1 dataset created
# qp09mr dataset created
# qp03qr dataset created
# qp03q0 dataset created
# qp093m dataset created
# qp08bp dataset created
# qp09st dataset created
# qp09gn dataset created
# qp09jf dataset created
# qp095x dataset created
# qp03pt dataset created
# qp093t dataset created
# qp08ck dataset created
# qp09sx dataset created
# qp090m dataset created
# qp03y2 dataset created
# qp099c dataset created
# qp0975 dataset created
# qp098d dataset created
# qp03w3 dataset created
# qp096n dataset created
# qp09ce dataset created
# qp09y5 dataset created
# qp0dj5 dataset created
# qp03zb dataset created
# qp09hx dataset created
# qp08b5 dataset created
# qp03xv dataset created
# qp098h dataset created
# qp09sy dataset created
# qp0djc dataset created
# qp09eh dataset created
# qp091x dataset created
# qp06pq dataset created
# qp08gj dataset created
# qp03np dataset created
# qp06p2 dataset created
# qp097m dataset created
# qp0d18 dataset created
# qp03z9 dataset created
# qp0999 dataset created
# qp090n dataset created
# qp099f dataset created
# qp094v dataset created
# qp0d11 dataset created
# qp09gq dataset created
# qp09hp dataset created
# qp09kw dataset created
# qp0957 dataset created
# qp03zh dataset created
# qp03mt dataset created
# qp03vb dataset created
# qp08g4 dataset created
# qp094n dataset created
# qp09ch dataset created
# qp0d04 dataset created
# qp091t dataset created
# qp0d5m dataset created
# qp095z dataset created
# qp091k dataset created
# qp09mz dataset created
# qp06pf dataset created
# qp03tw dataset created
# qp09tq dataset created
# qp09up dataset created
# qp0djd dataset created
# qp0988 dataset created
# qp03wq dataset created
# qp09ct dataset created
# qp09sb dataset created
# qp099q dataset created
# qp0d1y dataset created
# qp03te dataset created
# qp09se dataset created
# qp094c dataset created
# qp08bz dataset created
# qp09ej dataset created
# qp09cf dataset created
# qp03yt dataset created
# qp0952 dataset created
# qp09m2 dataset created
# qp0972 dataset created
# qp09kd dataset created
# qp09uk dataset created
# qp0998 dataset created
# qp09ke dataset created
# qp09su dataset created
# qp03tm dataset created
# qp02zq dataset created
# qp0dj2 dataset created
# qp09qp dataset created
# qp02z7 dataset created
# qp0930 dataset created
# qp03rr dataset created
# qp0994 dataset created
# qp09dq dataset created
# qp09kj dataset created
# qp0977 dataset created
# qp099x dataset created
# qp0904 dataset created
# qp06pd dataset created
# qp03qz dataset created
# qp093b dataset created
# qp02z5 dataset created
# qp09jz dataset created
# qp09v6 dataset created
# qp09c8 dataset created
# qp09hv dataset created
# qp0902 dataset created
# qp03rv dataset created
# qp08bw dataset created
# qp09ub dataset created
# qp09yj dataset created
# qp0d4v dataset created
# qp03pz dataset created
# qp09sq dataset created
# qp09f4 dataset created
# qp0d5c dataset created
# qp09ks dataset created
# qp03xg dataset created
# qp0dhq dataset created
# qp099n dataset created
# qp0d1n dataset created
# qp093e dataset created
# qp099u dataset created
# qp03w6 dataset created
# qp0dhk dataset created
# qp0928 dataset created
# qp09fe dataset created
# qp091v dataset created
# qp09d9 dataset created
# qp03pq dataset created
# qp03vf dataset created
# qp03p6 dataset created
# qp03nb dataset created
# qp09u2 dataset created
# qp09uq dataset created
# qp0907 dataset created
# qp03qe dataset created
# qp03nf dataset created
# qp09du dataset created
# qp09f3 dataset created
# qp099k dataset created
# qp08bd dataset created
# qp09ec dataset created
# qp095s dataset created
# qp03mm dataset created
# qp0d10 dataset created
# qp08bn dataset created
# qp09tj dataset created
# qp09hq dataset created
# qp02zv dataset created
# qp08fn dataset created
# qp09k6 dataset created
# qp09ve dataset created
# qp09g4 dataset created
# qp097g dataset created
# qp09jm dataset created
# qp09vg dataset created
# qp094e dataset created
# qp09j7 dataset created
# qp0936 dataset created
# qp08c5 dataset created
# qp09jp dataset created
# qp09vm dataset created
# qp02zn dataset created
# qp09vs dataset created
# qp09s1 dataset created
# qp06nv dataset created
# qp08bg dataset created
# qp09gc dataset created
# qp0932 dataset created
# qp0djq dataset created
# qp0dn5 dataset created
# qp09v8 dataset created
# qp096r dataset created
# qp09ey dataset created
# qp09c7 dataset created
# qp0dhf dataset created
# qp091g dataset created
# qp09sg dataset created
# qp03pc dataset created
# qp097w dataset created
# qp06p3 dataset created
# qp0dh5 dataset created
# qp09e0 dataset created
# qp03wu dataset created
# qp0d1j dataset created
# qp09e2 dataset created
# qp090h dataset created
# qp08fj dataset created
# qp03ry dataset created
# qp0d13 dataset created
# qp03xe dataset created
# qp0926 dataset created
# qp098f dataset created
# qp03t2 dataset created
# qp09cn dataset created
# qp09dr dataset created
# qp09ms dataset created
# qp03y8 dataset created
# qp09jk dataset created
# qp03qp dataset created
# qp09ur dataset created
# qp095p dataset created
# qp09s3 dataset created
# qp09gb dataset created
# qp09h7 dataset created
# qp0973 dataset created
# qp09ee dataset created
# qp09uh dataset created
# qp09k8 dataset created
# qp08fw dataset created
# qp09mt dataset created
# qp08fy dataset created
# qp09ff dataset created
# qp09je dataset created
# qp09yp dataset created
# qp091q dataset created
# qp08b7 dataset created
# qp096q dataset created
# qp09dx dataset created
# qp03vd dataset created
# qp0905 dataset created
# qp09tk dataset created
# qp0d0q dataset created
# qp091m dataset created
# qp09cq dataset created
# qp09g7 dataset created
# qp0d0t dataset created
# qp08cv dataset created
# qp02z6 dataset created
# qp09kn dataset created
# qp0d1d dataset created
# qp0dh7 dataset created
# qp09f8 dataset created
# qp03y3 dataset created
# qp09jt dataset created
# qp0dhv dataset created
# qp09tb dataset created
# qp02zf dataset created
# qp03t3 dataset created
# qp09mj dataset created
# qp09tm dataset created
# qp0dh1 dataset created
# qp08gm dataset created
# qp0dhd dataset created
# qp03rw dataset created
# qp03jr dataset created
# qp090v dataset created
# qp0937 dataset created
# qp0d03 dataset created
# qp08g7 dataset created
# qp093f dataset created
# qp0995 dataset created
# qp09vd dataset created
# qp08fh dataset created
# qp09gz dataset created
# qp09cr dataset created
# qp0dj3 dataset created
# qp0d55 dataset created
# qp09cz dataset created
# qp09v4 dataset created
# qp0d14 dataset created
# qp091r dataset created
# qp08cu dataset created
# qp08bv dataset created
# qp09tt dataset created
# qp03zq dataset created
# qp02zg dataset created
# qp0d1b dataset created
# qp09h4 dataset created
# qp09hz dataset created
# qp08be dataset created
# qp0908 dataset created
# qp02zu dataset created
# qp03p7 dataset created
# qp0d0y dataset created
# qp095g dataset created
# qp0d50 dataset created
# qp03tq dataset created
# qp06ng dataset created
# qp0dje dataset created
# qp09sv dataset created
# qp09kr dataset created
# qp09cb dataset created
# qp08gv dataset created
# qp0938 dataset created
# qp09me dataset created
# qp09y1 dataset created
# qp03mx dataset created
# qp06nt dataset created
# qp0djb dataset created
# qp09jx dataset created
# qp09gm dataset created
# qp03yz dataset created
# qp090y dataset created
# qp09c2 dataset created
# qp06p8 dataset created
# qp0dhm dataset created
# qp03p0 dataset created
# qp08bu dataset created
# qp0d1q dataset created
# qp090d dataset created
# qp09u7 dataset created
# qp02yf dataset created
# qp0dh3 dataset created
# qp0dn1 dataset created
# qp08b6 dataset created
# qp0d17 dataset created
# qp094s dataset created
# qp095d dataset created
# qp09qj dataset created
# qp09km dataset created
# qp08gw dataset created
# qp09ty dataset created
# qp09v3 dataset created
# qp09he dataset created
# qp09c6 dataset created
# qp0965 dataset created
# qp0967 dataset created
# qp03pm dataset created
# qp09m8 dataset created
# qp02z4 dataset created
# qp097p dataset created
# qp091e dataset created
# qp09m3 dataset created
# qp08b1 dataset created
# qp092z dataset created
# qp097q dataset created
# qp08bx dataset created
# qp0d5h dataset created
# qp08fp dataset created
# qp0955 dataset created
# qp091s dataset created
# qp03zy dataset created
# qp09y4 dataset created
# qp09y0 dataset created
# qp09np dataset created
# qp02z3 dataset created
# qp08fz dataset created
# qp09ck dataset created
# qp02yz dataset created
# qp09br dataset created
# qp08fv dataset created
# qp03pg dataset created
# qp09mf dataset created
# qp093n dataset created
# qp03nn dataset created
# qp0906 dataset created
# qp03tk dataset created
# qp09kq dataset created
# qp09q0 dataset created
# qp0d5j dataset created
# qp0943 dataset created
# qp0djg dataset created
# qp08bt dataset created
# qp09qn dataset created
# qp03p5 dataset created
# qp09vh dataset created
# qp095h dataset created
# qp08cj dataset created
# qp09mb dataset created
# qp0d57 dataset created
# qp09j9 dataset created
# qp09k5 dataset created
# qp0d1v dataset created
# qp08bs dataset created
# qp09bx dataset created
# qp099p dataset created
# qp03qt dataset created
# qp09j5 dataset created
# qp09te dataset created
# qp0dju dataset created
# qp0d5t dataset created
# qp0d1e dataset created
# qp09s4 dataset created
# qp0942 dataset created
# qp09cs dataset created
# qp09jr dataset created
# qp09jc dataset created
# qp08gk dataset created
# qp08g6 dataset created
# qp03v2 dataset created
# qp093j dataset created
# qp094d dataset created
# qp09mm dataset created
# qp06ny dataset created
# qp02yy dataset created
# qp09v7 dataset created
# qp03tr dataset created
# qp03y4 dataset created
# qp094f dataset created
# qp097n dataset created
# qp0dhj dataset created
# qp03zx dataset created
# qp09vf dataset created
# qp08up dataset created
# qp09m9 dataset created
# qp095f dataset created
# qp0956 dataset created
# qp0dnn dataset created
# qp0d0s dataset created
# qp0dn0 dataset created
# qp098b dataset created
# qp09jd dataset created
# qp097j dataset created
# qp0d5u dataset created
# qp03vc dataset created
# qp0d5d dataset created
# qp08ch dataset created
# qp09tu dataset created
# qp09jg dataset created
# qp08gs dataset created
# qp0dn4 dataset created
# qp091p dataset created
# qp09ts dataset created
# qp09h1 dataset created
# qp09qh dataset created
# qp09k7 dataset created
# qp09jy dataset created
# qp08fr dataset created
# qp09ju dataset created
# qp0966 dataset created
# qp03yr dataset created
# qp0d1s dataset created
# qp091d dataset created
# qp0djf dataset created
# qp09mc dataset created
# qp09h6 dataset created
# qp09bv dataset created
# qp03v3 dataset created
# qp09d0 dataset created
# qp09q1 dataset created
# qp0d1u dataset created
# qp09jb dataset created
# qp098v dataset created
# qp09tv dataset created
# qp093k dataset created
# qp0dnh dataset created
# qp09js dataset created
# qp091f dataset created
# qp090z dataset created
# qp0d5q dataset created
# qp09h3 dataset created
# qp0d1t dataset created
# qp0d0u dataset created
# qp09wh dataset created
# qp03yh dataset created
# qp09n4 dataset created
# qp09q4 dataset created
# qp08uj dataset created
# qp0d4j dataset created
# qp09fc dataset created
# qp09v5 dataset created
# qp08ft dataset created
# qp08gu dataset created
# qp09vc dataset created
# qp0964 dataset created
# qp097r dataset created
# qp0d44 dataset created
# qp09wn dataset created
# qp08fu dataset created
# qp09w0 dataset created
# qp03pj dataset created
# qp09t3 dataset created
# qp091h dataset created
# qp09tg dataset created
# qp0d5n dataset created
# qp09w4 dataset created
# qp09m6 dataset created
# qp08gh dataset created
# qp0d4h dataset created
# qp09vb dataset created
# qp09jj dataset created
# qp0917 dataset created
# qp09jw dataset created
# qp0939 dataset created
# qp0935 dataset created
# qp09gd dataset created
# qp06nw dataset created
# qp08fq dataset created
# qp0d08 dataset created
# qp09t7 dataset created
# qp09eg dataset created
# qp0d43 dataset created
# qp0931 dataset created
# qp09n1 dataset created
# qp03y5 dataset created
# qp02yv dataset created
# qp09mv dataset created
# qp09by dataset created
# qp09n0 dataset created
# qp09my dataset created
# qp08g5 dataset created
# qp02yu dataset created
# qp09dy dataset created
# qp0d5k dataset created
# qp0d5s dataset created
# qp09kg dataset created
# qp09m7 dataset created
# qp09s0 dataset created
# qp09n5 dataset created
# qp09w1 dataset created
# qp09nj dataset created
# qp09dz dataset created
# qp093h dataset created
# qp08fs dataset created
# qp0919 dataset created
# qp091j dataset created
# qp09s5 dataset created
# qp092b dataset created
# qp0d4m dataset created
# qp03yn dataset created
# qp09v9 dataset created
# qp0d45 dataset created

# %%
# GlobalParameter
nrofinputs = 50
trainRatio = 0.8

dict_of_model_arima = {};
dict_of_model_lr = {};
dict_of_model_gbr = {};
dict_of_model_rfr = {};
dict_of_model_lstm = {};
dict_of_results = {};
dict_of_nrofinputs = {};

isKeras = False;
isLSTM = False;
isLR = True;
isGBR = False;
count = 1;
isVisualizeResult = False;

# LinearRegressor
for geoHash in alluniqueGeohash:
    print("Linear Regression----------------------------", count, geoHash)
    df = parseToDateTime( dict_of_df[geoHash] );
    nrofinputs = getNrofInputs(dict_of_df[geoHash] );
    dict_of_nrofinputs[geoHash] = nrofinputs
    if( isVisualizeResult):
      plotData(df); 
    X_train, y_train, trainData, testData = splitTrainTest(df);
    if(len(X_train) > 0 and len(y_train ) > 0):
      dict_of_model_lr[geoHash] = buildLinearRegressor( X_train, y_train)
      predictedValues_lr = validate( dict_of_model_lr[geoHash], trainData, testData, isKeras )
      compileAndVisualizeResult( df, predictedValues_lr, isVisualizeResult, geoHash )
      exportModel( dict_of_model_lr[geoHash], geoHash, isKeras, isLR, isGBR )
    count = count + 1;
    
# Export expected number of inputs
f = open("nrofinputs.pkl","wb")
pickle.dump(dict_of_nrofinputs,f)
f.close()
# Out:
# Linear Regression---------------------------- 1 qp03wc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-498-0e2ea5345541> in <module>
#      23     df = parseToDateTime( dict_of_df[geoHash] );
#      24     nrofinputs = getNrofInputs(dict_of_df[geoHash] );
# ---> 25     dict_of_nrofinput[geoHash] = nrofinputs
#      26     if( isVisualizeResult):
#      27       plotData(df);
#
# NameError: name 'dict_of_nrofinput' is not defined

# %%
predict( "C:/Users/PXY/Desktop/training.csv","C:/Users/PXY/Desktop/Models_LR/" )
# Out:
# qp03wc dataset created
# qp03pn dataset created
# qp09sw dataset created
# qp0991 dataset created
# qp090q dataset created
# qp03tu dataset created
# qp096d dataset created
# qp03nr dataset created
# qp093r dataset created
# qp03r2 dataset created
# qp09kb dataset created
# qp03rp dataset created
# qp03w9 dataset created
# qp096m dataset created
# qp091u dataset created
# qp03md dataset created
# qp099z dataset created
# qp0990 dataset created
# qp03mf dataset created
# qp09fu dataset created
# qp091w dataset created
# qp0dhw dataset created
# qp09fh dataset created
# qp0961 dataset created
# qp03zr dataset created
# qp09de dataset created
# qp09g8 dataset created
# qp0d0k dataset created
# qp09m0 dataset created
# qp03yx dataset created
# qp09u8 dataset created
# qp09df dataset created
# qp0djh dataset created
# qp03rs dataset created
# qp03q7 dataset created
# qp03wp dataset created
# qp09u3 dataset created
# qp094k dataset created
# qp09bd dataset created
# qp03wm dataset created
# qp0d0j dataset created
# qp093d dataset created
# qp09kz dataset created
# qp06nc dataset created
# qp06pk dataset created
# qp03yv dataset created
# qp09bq dataset created
# qp09k0 dataset created
# qp06pe dataset created
# qp03w7 dataset created
# qp098e dataset created
# qp03q6 dataset created
# qp06n8 dataset created
# qp0925 dataset created
# qp09b2 dataset created
# qp096t dataset created
# qp09gh dataset created
# qp03y1 dataset created
# qp0djw dataset created
# qp09t8 dataset created
# qp094j dataset created
# qp09k3 dataset created
# qp09ss dataset created
# qp09hm dataset created
# qp03wt dataset created
# qp092d dataset created
# qp03rh dataset created
# qp03w0 dataset created
# qp03y9 dataset created
# qp09ge dataset created
# qp03ye dataset created
# qp096w dataset created
# qp03x3 dataset created
# qp03xu dataset created
# qp03mz dataset created
# qp093x dataset created
# qp09dk dataset created
# qp09hy dataset created
# qp0d19 dataset created
# qp09dm dataset created
# qp09sz dataset created
# qp06pw dataset created
# qp09gw dataset created
# qp02zz dataset created
# qp0dj0 dataset created
# qp03yk dataset created
# qp09g1 dataset created
# qp099b dataset created
# qp08fx dataset created
# qp09e5 dataset created
# qp09fd dataset created
# qp09tp dataset created
# qp09hj dataset created
# qp0900 dataset created
# qp0d5g dataset created
# qp09gy dataset created
# qp08gy dataset created
# qp09jq dataset created
# qp03yd dataset created
# qp094q dataset created
# Testing----------------------------- 1 qp03wc
# Testing----------------------------- 2 qp03pn
# Testing----------------------------- 3 qp09sw
# Testing----------------------------- 4 qp0991
# Testing----------------------------- 5 qp090q
# Testing----------------------------- 6 qp03tu
# Testing----------------------------- 7 qp096d
# Testing----------------------------- 8 qp03nr
# Testing----------------------------- 9 qp093r
# Testing----------------------------- 10 qp03r2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-505-6f51d596460b> in <module>
# ----> 1 predict( "C:/Users/PXY/Desktop/training.csv","C:/Users/PXY/Desktop/Models_LR/" )
#
# <ipython-input-504-e848cf990dfc> in predict(testFilepath, modelFolderpath)
#      18     for geoHash in alluniqueTestGeohash:
#      19         print("Testing-----------------------------", count, geoHash)
# ---> 20         df = parseToDateTime( dict_of_test_df[geoHash] );
#      21
#      22         nrofinputs = dict_of_nr_inputs[geoHash];
#
# <ipython-input-23-e4687f9dd6b4> in parseToDateTime(geospecificdata)
#       5   maxDay = max(geospecificdata['day']) + 1;
#       6
# ----> 7   for index,row in geospecificdata.iterrows():
#       8       historyStart = currentDate - timedelta(days= maxDay -row['day'])
#       9       dateTime = datetime.datetime.strptime( str( historyStart) + row['timestamp'], "%Y-%m-%d%H:%M")
#
# ~\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     844         klass = self._constructor_sliced
#     845         for k, v in zip(self.index, self.values):
# --> 846             s = klass(v, index=columns, name=k)
#     847             yield k, s
#     848
#
# ~\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     580
#     581             # we will try to copy be-definition here
# --> 582             subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     583
#     584     elif isinstance(data, ExtensionArray):
#
# ~\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\core\internals\construction.py in _try_cast(arr, take_fast_path, dtype, copy, raise_cast_failure)
#     702                                        isinstance(subarr, np.ndarray))):
#     703             subarr = construct_1d_object_array_from_listlike(subarr)
# --> 704         elif not is_extension_type(subarr):
#     705             subarr = construct_1d_ndarray_preserving_na(subarr, dtype,
#     706                                                         copy=copy)
#
# ~\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\core\dtypes\common.py in is_extension_type(arr)
#    1693     if is_categorical(arr):
#    1694         return True
# -> 1695     elif is_sparse(arr):
#    1696         return True
#    1697     elif is_datetime64tz_dtype(arr):
#
# ~\AppData\Local\conda\conda\envs\tf_gpu\lib\site-packages\pandas\core\dtypes\common.py in is_sparse(arr)
#     214     True
#     215     """
# --> 216     from pandas.core.arrays.sparse import SparseDtype
#     217
#     218     dtype = getattr(arr, 'dtype', arr)
#
# KeyboardInterrupt:
